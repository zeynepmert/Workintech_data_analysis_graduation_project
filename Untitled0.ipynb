# %% [markdown]
# <a href="https://colab.research.google.com/github/zeynepmert/Workintech_data_analysis_graduation_project/blob/tuba/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
customers= pd.read_csv('customers.csv')
orders= pd.read_csv('orders.csv')
products= pd.read_csv('products.csv')
sales= pd.read_csv('sales.csv')

# %%
sales.columns
# Out:
# Index(['sales_id', 'order_id', 'product_id', 'price_per_unit', 'quantity',
#        'total_price'],
#       dtype='object')

# %%
customers.columns
# Out:
# Index(['customer_id', 'customer_name', 'gender', 'age', 'home_address',
#        'zip_code', 'city', 'state', 'country'],
#       dtype='object')

# %%
orders.columns
# Out:
# Index(['order_id', 'customer_id', 'payment', 'order_date', 'delivery_date'], dtype='object')

# %%
products.columns
# Out:
# Index(['product_ID', 'product_type', 'product_name', 'size', 'colour', 'price',
#        'quantity', 'description'],
#       dtype='object')

# %%
orders['order_date']
# Out:
# 0      2021-8-30
# 1       2021-2-3
# 2      2021-10-8
# 3       2021-5-6
# 4      2021-3-23
#          ...
# 995    2021-1-13
# 996    2021-1-18
# 997     2021-5-5
# 998    2021-6-15
# 999     2021-4-7
# Name: order_date, Length: 1000, dtype: object
